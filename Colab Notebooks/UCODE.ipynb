# %%
import folium
from folium import plugins
import pandas as pd
import ipywidgets
import os
import json

# %%
# !git clone https://github.com/ujjwalyadav3003/UniNav
# Out:
# Cloning into 'UniNav'...
# remote: Enumerating objects: 80, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 80 (delta 3), reused 12 (delta 1), pack-reused 50
# Unpacking objects: 100% (80/80), 23.50 KiB | 962.00 KiB/s, done.

# %%
# the latitude and Longitude coordinates
UMMlocation = (13.115765, 77.635344)
map_UMM = folium.Map(location = UMMlocation, width = "85%", zoom_start = 20) 
map_UMM
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5e780db6fe657b809baf00f68a665788 {
#                     position: relative;
#                     width: 85.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5e780db6fe657b809baf00f68a665788&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5e780db6fe657b809baf00f68a665788 = L.map(
#                 &quot;map_5e780db6fe657b809baf00f68a665788&quot;,
#                 {
#                     center: [13.115765, 77.635344],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 20,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3bdd1b103ce449352e87039fe2f1957e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5e780db6fe657b809baf00f68a665788);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
hauseOutline = 'UniNav/build/Haus7.geojson'
display(folium.GeoJson(hauseOutline, name="Haus7").add_to(map_UMM))
display(map_UMM)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5e780db6fe657b809baf00f68a665788 {
#                     position: relative;
#                     width: 85.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5e780db6fe657b809baf00f68a665788&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5e780db6fe657b809baf00f68a665788 = L.map(
#                 &quot;map_5e780db6fe657b809baf00f68a665788&quot;,
#                 {
#                     center: [13.115765, 77.635344],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 20,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3bdd1b103ce449352e87039fe2f1957e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5e780db6fe657b809baf00f68a665788);
#
#
#
#         function geo_json_0fe6dbd502bbdadc099819a667344710_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_0fe6dbd502bbdadc099819a667344710 = L.geoJson(null, {
#                 onEachFeature: geo_json_0fe6dbd502bbdadc099819a667344710_onEachFeature,
#
#         });
#
#         function geo_json_0fe6dbd502bbdadc099819a667344710_add (data) {
#             geo_json_0fe6dbd502bbdadc099819a667344710
#                 .addData(data)
#                 .addTo(map_5e780db6fe657b809baf00f68a665788);
#         }
#             geo_json_0fe6dbd502bbdadc099819a667344710_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[77.63595875303702, 13.115713953605237], [77.63596266497592, 13.115659391063659], [77.63581870076689, 13.115652320269632], [77.6357519944612, 13.115649588895266], [77.63576198339189, 13.115500572409474], [77.63599966246721, 13.115516767885893], [77.63629419550784, 13.115544247519765], [77.63627861595938, 13.1156956962664], [77.63620896850557, 13.115688513887818], [77.63620530760994, 13.115736651154236], [77.63595875303702, 13.115713953605237]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
testGeoJson = 'UniNav/Rou/E7.geojson'

# %%
def switchPosition(coordinate):
  temp = coordinate[0]
  coordinate[0] = coordinate[1]
  coordinate[1] = temp
  return coordinate

# %%
with open(testGeoJson) as f:
  testWay = json.load(f)

for feature in testWay['features']:
    path = feature['geometry']['coordinates']
finalPath = list(map(switchPosition,path))
finalPath
# Out:
# [[13.11724298874094, 77.63439121694842],
#  [13.117256635021405, 77.63537004709087],
#  [13.117198150954977, 77.63546813027449],
#  [13.115878358611766, 77.6355682163757],
#  [13.11591149976158, 77.63598256778624],
#  [13.115732147599559, 77.63599858136615]]

# %%
path = 'UniNav/Rou/E7.geojson'
folium.plugins.AntPath([[13.11724298874094, 77.63439121694842],
 [13.117256635021405, 77.63537004709087],
 [13.117198150954977, 77.63546813027449],
 [13.115878358611766, 77.6355682163757],
 [13.11591149976158, 77.63598256778624],
 [13.115732147599559, 77.63599858136615]]).add_to(map_UMM)
map_UMM
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5e780db6fe657b809baf00f68a665788 {
#                     position: relative;
#                     width: 85.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-ant-path@1.1.2/dist/leaflet-ant-path.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5e780db6fe657b809baf00f68a665788&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5e780db6fe657b809baf00f68a665788 = L.map(
#                 &quot;map_5e780db6fe657b809baf00f68a665788&quot;,
#                 {
#                     center: [13.115765, 77.635344],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 20,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3bdd1b103ce449352e87039fe2f1957e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5e780db6fe657b809baf00f68a665788);
#
#
#
#         function geo_json_0fe6dbd502bbdadc099819a667344710_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_0fe6dbd502bbdadc099819a667344710 = L.geoJson(null, {
#                 onEachFeature: geo_json_0fe6dbd502bbdadc099819a667344710_onEachFeature,
#
#         });
#
#         function geo_json_0fe6dbd502bbdadc099819a667344710_add (data) {
#             geo_json_0fe6dbd502bbdadc099819a667344710
#                 .addData(data)
#                 .addTo(map_5e780db6fe657b809baf00f68a665788);
#         }
#             geo_json_0fe6dbd502bbdadc099819a667344710_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[77.63595875303702, 13.115713953605237], [77.63596266497592, 13.115659391063659], [77.63581870076689, 13.115652320269632], [77.6357519944612, 13.115649588895266], [77.63576198339189, 13.115500572409474], [77.63599966246721, 13.115516767885893], [77.63629419550784, 13.115544247519765], [77.63627861595938, 13.1156956962664], [77.63620896850557, 13.115688513887818], [77.63620530760994, 13.115736651154236], [77.63595875303702, 13.115713953605237]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             ant_path_a5e1e12126399c68271286371dfbaff5 = L.polyline.antPath(
#               [[13.11724298874094, 77.63439121694842], [13.117256635021405, 77.63537004709087], [13.117198150954977, 77.63546813027449], [13.115878358611766, 77.6355682163757], [13.11591149976158, 77.63598256778624], [13.115732147599559, 77.63599858136615]],
#               {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#0000FF&quot;, &quot;dashArray&quot;: [10, 20], &quot;dashOffset&quot;: null, &quot;delay&quot;: 400, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;hardwareAcceleration&quot;: false, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.5, &quot;paused&quot;: false, &quot;pulseColor&quot;: &quot;#FFFFFF&quot;, &quot;reverse&quot;: false, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#         ).addTo(map_5e780db6fe657b809baf00f68a665788);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
select_widget=ipywidgets.Select(
    options=['Source', 'Destination'],
    value='Source',
    description='Select',
    disabled=False)

def selectOption(opt):
    if opt == 'Source':
        print('Source')
    if opt == 'Destination':
        print('Destination')

ipywidgets.interact(selectOption, opt=select_widget)
# Out:
# interactive(children=(Select(description='Select', options=('Source', 'Destination'), value='Source'), Output(…
# <function __main__.selectOption(opt)>

# %%
class navigator:
    def __init__(self):
        self.geoResources = {}
        self.hosLocation =(13.115765, 77.635344)
        self.position = 'E'
        self.destination = 'Haus2'

        for root, dirs, files in os.walk('UniNav'):  
            for file in files:
                self.geoResources[file.split('.')[0]] = root+'/'+file

    def changeDestination(self,newDestination):
        self.destination = newDestination
        self.redrawMap()

    def changeStartPoint(self, newStartPoint):
        
        #self.position = newStartPoint #does not work yet
        print(f'Selected Start: {newStartPoint}; Selected Target: {self.destination}')
        #self.redrawMap()
        

    def drawPathWay(self,hosMap):
      
      def switchPosition(coordinate):
        temp = coordinate[0]
        coordinate[0] = coordinate[1]
        coordinate[1] = temp
        return coordinate

      searchString = self.position + self.destination.split('Haus')[1]
      with open(self.geoResources[searchString]) as f:
           testWay = json.load(f)

      for feature in testWay['features']:
        path = feature['geometry']['coordinates']

      finalPath = list(map(switchPosition,path))
      folium.plugins.AntPath(finalPath).add_to(hosMap)

    def drawBuilding(self,hosMap):
      hauseOutline = self.geoResources[self.destination]
      folium.GeoJson(hauseOutline, name="geojson").add_to(hosMap)

    def redrawMap(self):
        #print(f'position {self.position}, destination {self.destination}')
        hosMap = folium.Map(location = self.hosLocation, width = "75%", zoom_start = 17)
        self.drawPathWay(hosMap)
        self.drawBuilding(hosMap)
        display(hosMap)

# %%
myNavigator = navigator()

# %%
def displayWay(whereTo):
     myNavigator.changeDestination(whereTo)

# %%
def changePosition(whereFrom):
    myNavigator.changeStartPoint(whereFrom)

# %%
# Destination Selector
selectHouse_widget=ipywidgets.Select(
    
options=['Haus1',
    'Haus10',
    'Haus2',
    'Haus3',
    'Haus4',
    'Haus5',
    'Haus6',
    'Haus7',
    'Haus8',
    'Haus9'],
    value='Haus1',
    description='Target',
    disabled=False)

# widget function
def selectHouse(way):
    if way == 'Haus1' :
        displayWay('Haus1' ) 
    if way == 'Haus10':
        displayWay('Haus10')
    if way == 'Haus2' :
        displayWay('Haus2' ) 
    if way == 'Haus3' :
        displayWay('Haus3' ) 
    if way == 'Haus4' :
        displayWay('Haus4' ) 
    if way == 'Haus5' :
        displayWay('Haus5' ) 
    if way == 'Haus6' :
        displayWay('Haus6' ) 
    if way == 'Haus7' :
        displayWay('Haus7' ) 
    if way == 'Haus8' :
        displayWay('Haus8' ) 
    if way == 'Haus9' :
        displayWay('Haus9' ) 

# Position Selector
selectPosition_widget=ipywidgets.Select(
    options=['CVR', 'Entarance', 'Foodcourt', 'Library'],
    value='Entarance',
    description='Start',
    disabled=False)

def selectPosition(position):
    if position == 'CVR':
        changePosition('C')
    if position == 'Entarance':
        changePosition('E')
    if position == 'Foodcourt':
        changePosition('f')
    if position == 'Library':
        changePosition('l')
        
#Initialization   
ipywidgets.interact(selectPosition, position=selectPosition_widget)
ipywidgets.interact(selectHouse, way=selectHouse_widget)
# Out:
# interactive(children=(Select(description='Start', index=1, options=('CVR', 'Entarance', 'Foodcourt', 'Library'…
# interactive(children=(Select(description='Target', options=('Haus1', 'Haus10', 'Haus2', 'Haus3', 'Haus4', 'Hau…
# <function __main__.selectHouse(way)>
